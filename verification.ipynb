# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Nu = 0.12   
Ns = 0.012

# %%
nt = 50000

w0 = 0.1
bu0 = 0.5
bs0 = 0.1

w, bu, bs = nlm_lf(w0, bu0, bs0, nt=nt)

# %%
#plt.plot(w)
plt.plot(bu, label='bu')
plt.plot(bs, label='bs')
plt.legend()
plt.title('always in saturated phase?')
# Out:
# Text(0.5, 1.0, 'always in saturated phase?')

# %%
M = bu/Nu**2 - bs/Ns**2
print(M[:10])
# Out:
# [-659.72222222 -659.72222222 -659.72222222 -659.72222222 -659.72222222
#  -659.72222222 -659.72222222 -659.72222222 -659.72222222 -659.72222222]

# %% [markdown]
# ### TLM

# %%
# initial condition for perturbaitons are all zeros, 
h = 1e-4
wp0 = h
bup0 = 2*h
bsp0 = 2*h

wp, bup, bsp = tlm_lf(w0, bu0, bs0, wp0, bup0, bsp0)
tlm_pert = [wp, bup, bsp]

# %%
nrows = 1
ncols = 3
fig,ax = plt.subplots(nrows=nrows,
                      ncols=ncols, figsize=(16,5))
sens_subplots(wp, ax[0], "leap frog TLM w'")
sens_subplots(bup, ax[1], "bu'")
sens_subplots(bsp, ax[2], "bs'")

# %%
# initial condition for basic state  # always in saturated phase
#w0 = 0.1
#bu0 = 0.1
#bs0 = 0.15 

# initial condition for basic state  # phase change
#w0 = 0.1
#bu0 = 0.5
#bs0 = 0.1

# initial condition for perturbaitons are all zeros, 
#wp0 = 0.01
#bup0 = 0.001
#bsp0 = 0.002

w_ctrl, bu_ctrl, bs_ctrl = nlm_lf(w0, bu0, bs0, nt=nt)
w_nlmp, bu_nlmp, bs_nlmp = nlm_lf(w0+wp0, bu0+bup0, bs0+bsp0, nt=nt)
w_diff = w_nlmp - w_ctrl
bu_diff = bu_nlmp - bu_ctrl
bs_diff = bs_nlmp - bs_ctrl

# %%
nrows = 1
ncols = 3
fig,ax = plt.subplots(nrows=nrows,
                      ncols=ncols, figsize=(16,5))
sens_subplots(w_diff, ax[0], "leap frog NLM w'")
sens_subplots(bu_diff, ax[1], "bu'")
sens_subplots(bs_diff, ax[2], "bs'")

# %% [markdown]
# #### TLM correctness
# $\Phi (\alpha) = \frac{||Q_r(z+\alpha h) - Q_r(z)||}{||\alpha P_r h||} = 1+\mathcal{O}(\alpha)$

# %%
alpha = 1e-4
h = (1,2,2)
cw, cbu, cbs = h
caw = cw*alpha; cabu = cbu*alpha; cabs = cbs*alpha
w_ctrl, bu_ctrl, bs_ctrl = nlm_lf(w0, bu0, bs0, nt=nt)
w_nlmp, bu_nlmp, bs_nlmp = nlm_lf(w0+caw, bu0+cabu, bs0+cabs, nt=nt)

w_tlmc, bu_tlmc, bs_tlmc = tlm_lf(w0, bu0, bs0, cw, cbu, cbs)
w_diff = w_nlmp - w_ctrl
bu_diff = bu_nlmp - bu_ctrl
bs_diff = bs_nlmp - bs_ctrl

#c = np.sqrt(w_diff**2) + np.sqrt(bu_diff**2) + np.sqrt(bs_diff**2)
#d = np.sqrt((alpha*w_tlmc)**2)+ np.sqrt((alpha*bu_tlmc)**2) + np.sqrt((alpha*bs_tlmc)**2)

c = np.sqrt(w_diff**2 + bu_diff**2 + bs_diff**2)
d = np.sqrt((alpha*w_tlmc)**2 + (alpha*bu_tlmc)**2 + (alpha*bs_tlmc)**2)

phi = c/d

# %%
plt.plot(phi[:]-1)
plt.title(f'error should < {alpha:.1e}')
# Out:
# Text(0.5, 1.0, 'error should < 1.0e-04')

# %%
plt.plot(phi[:4000]-1)
plt.title(f'error should < {alpha:.1e} in one phase')
# Out:
# Text(0.5, 1.0, 'error should < 1.0e-04 in one phase')

# %% [markdown]
# ## Fortran output

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sens_subplots(var, ax, title):
    cs = ax.plot(var)
    ax.set_title(title)

# %%
a = pd.read_csv('MAFD/fort.16', delim_whitespace=True, 
                header=None, names=['a_w', 'a_bu', 'a_bs'])
a_w = a.a_w.values[::-1]
a_bu = a.a_bu.values[::-1]
a_bs = a.a_bs.values[::-1]

nrows = 1
ncols = 3
fig,ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12,5))
sk = 1
sens_subplots(a_w[::sk], ax[0], 'sensitivity to w')
sens_subplots(a_bu[::sk], ax[1], 'sensitivity to bu')
sens_subplots(a_bs[::sk], ax[2], 'sensitivity to bs')

#sens_subplots(a_w[1::sk], ax[0], 'sensitivity to w')
#sens_subplots(a_bu[1::sk], ax[1], 'sensitivity to bu')
#sens_subplots(a_bs[1::sk], ax[2], 'sensitivity to bs')

# %%
a = pd.read_csv('MAFD/fort.15', delim_whitespace=True, 
                header=None, names=['w_prime', 'bu_prime', 'bs_prime'])
w_prime = a.w_prime.values
bu_prime = a.bu_prime.values
bs_prime = a.bs_prime.values

# %%
nrows = 1
ncols = 3
fig,ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16,5))
sens_subplots(w_prime, ax[0], "w\'")
sens_subplots(bu_prime, ax[1], "bu\'")
sens_subplots(bs_prime, ax[2], "bs\'")

# %%
nrows = 1
ncols = 3
fig,ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16,5))
sens_subplots(w_prime, ax[0], "w\'")
sens_subplots(bu_prime, ax[1], "bu\'")
sens_subplots(bs_prime, ax[2], "bs\'")

sens_subplots(w_diff, ax[0], "w\'")
sens_subplots(bu_diff, ax[1], "bu\'")
sens_subplots(bs_diff, ax[2], "bs\'")

# %%
sk = 2
plt.plot(bu_prime[1::sk])
plt.plot(bs_prime[1::sk]*100)
plt.plot(w_prime[1::sk])

a = np.where((sk_prime[1:]-sk_prime[:-1])>0.018)[0]
b = np.where((a[1:]- a[:-1])>4)[0]

plt.scatter(a[b]*2, w_prime[a[b]*2])
a[b]*2
# Out:
# array([  202,  4880,  9558, 14234, 18912, 23590, 28268, 32946, 37622,
#        42300])

# %%
w_prime.size, a_w.size
# Out:
# (5000, 5000)

# %%
dR = w_prime*a_w + bu_prime*a_bu + bs_prime*a_bs
#plt.plot(dR)
sk=2
plt.plot(dR[::sk])
plt.plot(dR[1::sk])
print(dR[:10])

# %%
a = pd.read_csv('MAFD/fort.14', delim_whitespace=True, 
                header=None, names=['w', 'bu', 'bs'])
w_for = a.w.values
bu_for = a.bu.values
bs_for = a.bs.values

nrows = 1
ncols = 2
fig,ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12,5))
sens_subplots(w_for, ax[0], 'w')
ax[1].plot(bu_for, label='bu')
ax[1].plot(bs_for, label='bs')
ax[1].legend()

# %% [markdown]
# ## Functions

# %%
def sens_subplots(var, ax, title):
    cs = ax.plot(var)
    ax.set_title(title)
    
def nlm_lf(w0, bu0, bs0, nt=50000):
    w = np.zeros(nt)
    bu = np.zeros(nt)
    bs = np.zeros(nt)
    
    w[0] = w0
    bs[0] = bs0
    bu[0] = bu0
    
    dt = 0.1
    
    # leap frog
    for t in range(1):
        if bs[t] > bu[t]:
            w[t+1] = w[t] + bs[t]*dt
        else:
            w[t+1] = w[t] + bu[t]*dt

        bu[t+1] = bu[t] - (Nu**2)*w[t]*dt
        bs[t+1] = bs[t] - (Ns**2)*w[t]*dt



    for t in range(1,nt-1):
        if bs[t] > bu[t]:
            w[t+1] = w[t-1] + bs[t]*2.*dt
        else:
            w[t+1] = w[t-1] + bu[t]*2.*dt

        bu[t+1] = bu[t-1] - (Nu**2)*w[t]*2.*dt
        bs[t+1] = bs[t-1] - (Ns**2)*w[t]*2.*dt
   
    return w, bu, bs

def tlm_lf(w0, bu0, bs0, wp0, bup0, bsp0, nt=50000, dt=0.1):
    
    # basic state?
    w = np.zeros(nt)
    bu = np.zeros(nt)
    bs = np.zeros(nt)

    # p for prime, perturbation
    wp = np.zeros(nt)
    bup = np.zeros(nt)
    bsp = np.zeros(nt)
    
    # initial condition for basic state
    w[0] = w0
    bu[0] = bu0
    bs[0] = bs0

    # initial condition for perturbaitons are all zeros, 
    wp[0] = wp0
    bup[0] = bup0
    bsp[0] = bsp0
    
    for t in range(1):
        if bs[t] > bu[t]:
            wp[t+1] = wp[t] + dt*bup[t]
            w[t+1] = w[t] + bs[t]*dt
        else:
            wp[t+1] = wp[t] + dt*bsp[t]
            w[t+1] = w[t] + bu[t]*dt

        bup[t+1] = bup[t] - (Nu**2)*wp[t]*dt
        bu[t+1] = bu[t] - (Nu**2)*w[t]*dt
        bsp[t+1] = bsp[t] - (Ns**2)*wp[t]*dt
        bs[t+1] = bs[t] - (Ns**2)*w[t]*dt



    for t in range(1,nt-1):
        if bs[t] > bu[t]:
            w[t+1] = w[t-1] + bs[t]*2.*dt
            wp[t+1] = wp[t-1] + bsp[t]*2.*dt
        else:
            w[t+1] = w[t-1] + bu[t]*2.*dt
            wp[t+1] = wp[t-1] + bup[t]*2.*dt

        bu[t+1] = bu[t-1] - (Nu**2)*w[t]*2.*dt
        bup[t+1] = bup[t-1] - (Nu**2)*wp[t]*2.*dt
        bs[t+1] = bs[t-1] - (Ns**2)*w[t]*2.*dt
        bsp[t+1] = bsp[t-1] - (Ns**2)*wp[t]*2.*dt

    return wp, bup, bsp

# %% [markdown]
# $$b=\begin{cases} \theta_e + \left( R_{vd}\frac{c_p\theta_0}{L_v}-1 \right) q_t \ \ \ \ \ \ \ \ \ \text{if} q_t \lt q_vs, \ b_u \\
# \theta_e + \left( R_{vd}\frac{c_p\theta_0}{L_v}-1\right) q_{vs} -  \frac{c_p\theta_0}{L_v}(q_t-q_{vs})\ \  \text{if} q_t \geq q_vs, \ b_s
# \end{cases}  (2.26)$$
#
# $$N_u^2 = \frac{g}{\theta_0}\frac{d\tilde{\theta}}{dz}   (2.29)$$
# $$N_u^2 = \frac{g}{\theta_0}\frac{d\tilde{\theta_e}}{dz}$$
#
# $$ \frac{c_p \theta_0}{L_v} \approx 0.1 \to \theta_0 = 250K$$
# $$d\tilde{\theta}/dz=3K/km, d\tilde{q_v}/dz=-0.6g/kg/km, N_u^2\approx 2N_s^2$$

# %% [raw]
# N2 = np.sqrt(9.8/250*Lv/Cp*(0.003/800))
# #Nu^2 = N1^2 + N2^2
# Nu = 1.2e-2
# Ns = Nu/np.sqrt(2)
# Ns

# %% [markdown]
# identify the dependent variables: <br>
# w bu bs qt theta_e

# %% [markdown]
# dependent: w bu bs qt theta_e
# independent: nt dt qvs nu ns cp lv epsi theta

# %% [raw]
# # set constants
# nt = 1000
# qvs = 0.008       # assume the saturation mixing ratio is 8g/kg
# Nu = 1.2e-2      # Holton pp 58
# Ns = 0.008
# epsilon = 0.1  # Fr = Ro = 10−1, the influence of waves on the slow component is
#                 # relatively small, but does not decrease proportional to Fr and Ro,
#                 # as Fr and Ro are decreased to 10−2 and 10−3
# Cp = 1005
# Lv = 2.5e6 #J/kg
# dt = 0.001 #s
# timestep = np.arange(0,1,dt)
#
# # create variables
# w = np.zeros(nt)
# bu = np.zeros(nt)
# bs = np.zeros(nt)
# qt = np.zeros(nt)
# theta_e = np.zeros(nt)
# theta = 250  #K
#
# # set initial conditions
# qt[0] = 0.0078
#     # assumption, revise later
# qv = qt[0]
# theta_e[0] = theta + Lv/Cp*qv  # assume theta doesn't change with time
# w[0] = 0.1
# bs[0] = theta_e[0] + (epsilon-1)*qvs - epsilon*(qt[0]-qvs)
# bu[0] = theta_e[0] + (epsilon-1)*qt[0]

# %% [markdown]
# $$\frac{dw}{dt}=b=N_ub_uH_u + N_sb_sH_s$$
# $$\frac{db_u}{dt}=-N_uw$$
# $$\frac{db_s}{dt}=-N_sw$$
# $$b = H_ub_u + H_sb_s$$
# $$H_u = \begin{cases} 1 \ \ \text{if} q_t \lt q_vs, \\
# 0 \ \  \text{if} q_t \geq q_vs
# \end{cases}  (2.50)$$
# $$b_u = \theta_e + (\epsilon - 1)q_t$$
# $$b_s = \theta_e + (\epsilon - 1)q_{vs} - \epsilon(q_t-q_{vs}) \ \ \ \ (2.51)$$
# $$\theta + Lv/Cp min(qt, qvs)= \theta_e \ \ \ \ (2.13)$$

# %% [raw]
# for t in range(nt-1):
#
#     bu[t+1] = bu[t] - Nu * w[t] * dt
#     bs[t+1] = bs[t] - Ns * w[t] * dt
#
#     if qt[t]<qvs:
#         w[t+1] = w[t] + Nu*bu[t] * dt
#         # use theta_e[t] or theta_e[t+1]?
#         qt[t+1] = (bu[t+1] - theta_e[t]) / (epsilon - 1)
#     else:
#         w[t+1] = w[t] + Ns*bs[t] * dt
#         qt[t+1] = (theta_e[t] + (epsilon - 1)*qvs - bs[t])/epsilon + qvs
#
#     theta_e[t+1] = theta_e[t]# + Lv/Cp*(qt[t+1]-qt[t]) * dt
